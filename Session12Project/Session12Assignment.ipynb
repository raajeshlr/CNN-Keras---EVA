# %% [markdown]
# ### Added OneCycleLR
# ### Written a custom function for cropping, padding and cutout.
# ### Used old model as i will change the model to Resnet18 in 13th Assignment.

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Add, BatchNormalization
from keras.layers import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
import keras
from keras.regularizers import l2
from keras import regularizers
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import cv2
import keras
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_rows, img_cols,img_channels =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras import regularizers
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback
from keras import optimizers

# %%
print (num_classes)
print (num_train)
print (train_features.shape)
# Out:
# 10
# 50000
# (50000, 32, 32, 3)

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
def get_random_eraser_and_crop(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, random_crop_size=(32, 32), padding_for_crop=4,pixel_level=False):
  
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img
      
    def random_crop(input_img):
        
        # Note: image_data_format is 'channel_last'
        assert input_img.shape[2] == 3
        
        img = cv2.copyMakeBorder(input_img, padding_for_crop, padding_for_crop, padding_for_crop, padding_for_crop, cv2.BORDER_REPLICATE)
        
        height, width = img.shape[0], img.shape[1]
        
        dy, dx = random_crop_size
        
        x = np.random.randint(0, width - dx + 1)
        
        y = np.random.randint(0, height - dy + 1)
        
        return img[y:(y+dy), x:(x+dx), :]
      
    def do_preproc(input_image):
      
      return eraser(random_crop(input_image))
      
    return do_preproc

# %%
#Generator for training dataset.
datagen = ImageDataGenerator(horizontal_flip=True,featurewise_center=True, featurewise_std_normalization=True,preprocessing_function=get_random_eraser_and_crop(v_l=0,v_h=1))
datagen.fit(train_features)
train_generator = datagen.flow(train_features,train_labels,batch_size=128,shuffle=False)
batchX, batchy = train_generator.next()
print(batchX.shape,batchX.mean(),batchX.std())
# Out:
# (128, 32, 32, 3) -0.030019887 1.0029794

# %%
#Generator for test dataset.
datagen_test = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
datagen_test.fit(test_features)
test_generator = datagen_test.flow(test_features,test_labels,batch_size=128,shuffle=False)
batchX, batchy = test_generator.next()
print(batchX.shape,batchX.mean(),batchX.std())
# Out:
# (128, 32, 32, 3) -0.032796822 1.0182288

# %% [markdown]
# ## Used my 11th Assignment model. I will change to Resnet18 in assignment 13.

# %%
# Define the model
model1 = Sequential()
model1.add(Convolution2D(32, 3, 3, border_mode='same',kernel_regularizer=regularizers.l2(0.0001), input_shape=(32, 32, 3)))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.2))

model1.add(Convolution2D(32, 1, 1))


model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.3))

model1.add(Convolution2D(32, 1, 1))


model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(256, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.5))

model1.add(Convolution2D(10, 1, 1))

model1.add(AveragePooling2D(pool_size = (4,4)))
model1.add(Flatten())


model1.add(Activation('softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 12:34:19.760303 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#
# W0730 12:34:19.810914 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0730 12:34:19.820055 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0730 12:34:19.890950 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0730 12:34:19.892305 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0730 12:34:23.844985 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
#
# W0730 12:34:24.131128 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0730 12:34:24.143316 140133304858496 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# W0730 12:34:24.703129 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         36992
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 10)          2570
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 455,370
# Trainable params: 454,026
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
# For retrieving the saved best results
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## OneCycle LR

# %%
class CyclicLR(keras.callbacks.Callback):
    
    def __init__(self,base_lr, max_lr, step_size, base_m, max_m, cyclical_momentum):
 
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.base_m = base_m
        self.max_m = max_m
        self.cyclical_momentum = cyclical_momentum
        self.step_size = step_size
        
        self.clr_iterations = 0.
        self.cm_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}
        
    def clr(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)          
            return self.base_lr-(self.base_lr-self.base_lr/100)*np.maximum(0,(1-x))
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0,(1-x))
    
    def cm(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1) 
            return self.max_m
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.max_m - (self.max_m-self.base_m)*np.maximum(0,(1-x))
        
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())
            
        if self.cyclical_momentum == True:
            if self.clr_iterations == 0:
                K.set_value(self.model.optimizer.momentum, self.cm())
            else:
                K.set_value(self.model.optimizer.momentum, self.cm())
            
            
    def on_batch_begin(self, batch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)
        
        if self.cyclical_momentum == True:
            self.history.setdefault('momentum', []).append(K.get_value(self.model.optimizer.momentum))

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())
        
        if self.cyclical_momentum == True:
            K.set_value(self.model.optimizer.momentum, self.cm())

# %%
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras import optimizers

# %% [markdown]
# ## Max_LR = 0.01 (From 11th Assignment LR Finder Best Learning Rate).
# ## Min_LR = Max_LR / 10

# %%
batch_size = 64
epochs = 10
max_lr = 0.01
base_lr = max_lr/10
max_m = 0.98
base_m = 0.85

# %%
cyclical_momentum = True
augment = True
cycles = 2.35

# %%
iterations = round(len(train_features)/batch_size*epochs)
iterations = list(range(0,iterations+1))
step_size = len(iterations)/(cycles)

# %%
model1.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# W0730 12:35:06.080026 140133304858496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0730 12:35:06.117829 140133304858496 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
clr =  CyclicLR(base_lr=base_lr,
                max_lr=max_lr,
                step_size=step_size,
                max_m=max_m,
                base_m=base_m,
                cyclical_momentum=cyclical_momentum)

# %%
# Defining checkpoints
from keras.callbacks import ModelCheckpoint
filepath="/content/gdrive/My Drive/Raajesh-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
callbacks_list.append(clr)

# %% [markdown]
# ## Ran for 100 Epochs.
#
# ### Max Training Accuracy : 97.0
# ### Max Validation Accuray : 97.3

# %%
model1.fit_generator(
        train_generator,
        steps_per_epoch=np.ceil(50000/128),
        epochs=100,
        validation_data=test_generator,
        callbacks=callbacks_list,
        validation_steps=np.ceil(10000/128))
# Out:
# Epoch 1/100
# 391/391 [==============================] - 33s 85ms/step - loss: 0.3284 - acc: 0.8992 - val_loss: 0.2806 - val_acc: 0.9070
#
# Epoch 00001: val_acc improved from -inf to 0.90704, saving model to /content/gdrive/My Drive/Raajesh-01-0.91.hdf5
# Epoch 2/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2828 - acc: 0.9070 - val_loss: 0.2577 - val_acc: 0.9141
#
# Epoch 00002: val_acc improved from 0.90704 to 0.91412, saving model to /content/gdrive/My Drive/Raajesh-02-0.91.hdf5
# Epoch 3/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2647 - acc: 0.9125 - val_loss: 0.2392 - val_acc: 0.9217
#
# Epoch 00003: val_acc improved from 0.91412 to 0.92166, saving model to /content/gdrive/My Drive/Raajesh-03-0.92.hdf5
# Epoch 4/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2510 - acc: 0.9179 - val_loss: 0.2307 - val_acc: 0.9248
#
# Epoch 00004: val_acc improved from 0.92166 to 0.92481, saving model to /content/gdrive/My Drive/Raajesh-04-0.92.hdf5
# Epoch 5/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2404 - acc: 0.9211 - val_loss: 0.2263 - val_acc: 0.9263
#
# Epoch 00005: val_acc improved from 0.92481 to 0.92633, saving model to /content/gdrive/My Drive/Raajesh-05-0.93.hdf5
# Epoch 6/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2316 - acc: 0.9244 - val_loss: 0.2043 - val_acc: 0.9345
#
# Epoch 00006: val_acc improved from 0.92633 to 0.93450, saving model to /content/gdrive/My Drive/Raajesh-06-0.93.hdf5
# Epoch 7/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2242 - acc: 0.9266 - val_loss: 0.2035 - val_acc: 0.9346
#
# Epoch 00007: val_acc improved from 0.93450 to 0.93462, saving model to /content/gdrive/My Drive/Raajesh-07-0.93.hdf5
# Epoch 8/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2191 - acc: 0.9283 - val_loss: 0.1971 - val_acc: 0.9368
#
# Epoch 00008: val_acc improved from 0.93462 to 0.93685, saving model to /content/gdrive/My Drive/Raajesh-08-0.94.hdf5
# Epoch 9/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2131 - acc: 0.9306 - val_loss: 0.1914 - val_acc: 0.9395
#
# Epoch 00009: val_acc improved from 0.93685 to 0.93949, saving model to /content/gdrive/My Drive/Raajesh-09-0.94.hdf5
# Epoch 10/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2082 - acc: 0.9325 - val_loss: 0.1875 - val_acc: 0.9404
#
# Epoch 00010: val_acc improved from 0.93949 to 0.94045, saving model to /content/gdrive/My Drive/Raajesh-10-0.94.hdf5
# Epoch 11/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2040 - acc: 0.9342 - val_loss: 0.1835 - val_acc: 0.9419
#
# Epoch 00011: val_acc improved from 0.94045 to 0.94193, saving model to /content/gdrive/My Drive/Raajesh-11-0.94.hdf5
# Epoch 12/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2002 - acc: 0.9356 - val_loss: 0.1799 - val_acc: 0.9429
#
# Epoch 00012: val_acc improved from 0.94193 to 0.94293, saving model to /content/gdrive/My Drive/Raajesh-12-0.94.hdf5
# Epoch 13/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1965 - acc: 0.9370 - val_loss: 0.1720 - val_acc: 0.9461
#
# Epoch 00013: val_acc improved from 0.94293 to 0.94606, saving model to /content/gdrive/My Drive/Raajesh-13-0.95.hdf5
# Epoch 14/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1932 - acc: 0.9382 - val_loss: 0.1705 - val_acc: 0.9465
#
# Epoch 00014: val_acc improved from 0.94606 to 0.94646, saving model to /content/gdrive/My Drive/Raajesh-14-0.95.hdf5
# Epoch 15/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1895 - acc: 0.9394 - val_loss: 0.1675 - val_acc: 0.9476
#
# Epoch 00015: val_acc improved from 0.94646 to 0.94756, saving model to /content/gdrive/My Drive/Raajesh-15-0.95.hdf5
# Epoch 16/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1874 - acc: 0.9401 - val_loss: 0.1771 - val_acc: 0.9432
#
# Epoch 00016: val_acc did not improve from 0.94756
# Epoch 17/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1855 - acc: 0.9409 - val_loss: 0.1642 - val_acc: 0.9487
#
# Epoch 00017: val_acc improved from 0.94756 to 0.94870, saving model to /content/gdrive/My Drive/Raajesh-17-0.95.hdf5
# Epoch 18/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1816 - acc: 0.9420 - val_loss: 0.1639 - val_acc: 0.9494
#
# Epoch 00018: val_acc improved from 0.94870 to 0.94942, saving model to /content/gdrive/My Drive/Raajesh-18-0.95.hdf5
# Epoch 19/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1788 - acc: 0.9430 - val_loss: 0.1600 - val_acc: 0.9503
#
# Epoch 00019: val_acc improved from 0.94942 to 0.95035, saving model to /content/gdrive/My Drive/Raajesh-19-0.95.hdf5
# Epoch 20/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1769 - acc: 0.9441 - val_loss: 0.1555 - val_acc: 0.9515
#
# Epoch 00020: val_acc improved from 0.95035 to 0.95150, saving model to /content/gdrive/My Drive/Raajesh-20-0.95.hdf5
# Epoch 21/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1741 - acc: 0.9448 - val_loss: 0.1529 - val_acc: 0.9530
#
# Epoch 00021: val_acc improved from 0.95150 to 0.95300, saving model to /content/gdrive/My Drive/Raajesh-21-0.95.hdf5
# Epoch 22/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1727 - acc: 0.9452 - val_loss: 0.1496 - val_acc: 0.9537
#
# Epoch 00022: val_acc improved from 0.95300 to 0.95373, saving model to /content/gdrive/My Drive/Raajesh-22-0.95.hdf5
# Epoch 23/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1713 - acc: 0.9459 - val_loss: 0.1512 - val_acc: 0.9539
#
# Epoch 00023: val_acc improved from 0.95373 to 0.95386, saving model to /content/gdrive/My Drive/Raajesh-23-0.95.hdf5
# Epoch 24/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1695 - acc: 0.9466 - val_loss: 0.1486 - val_acc: 0.9547
#
# Epoch 00024: val_acc improved from 0.95386 to 0.95466, saving model to /content/gdrive/My Drive/Raajesh-24-0.95.hdf5
# Epoch 25/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1690 - acc: 0.9468 - val_loss: 0.1487 - val_acc: 0.9547
#
# Epoch 00025: val_acc improved from 0.95466 to 0.95474, saving model to /content/gdrive/My Drive/Raajesh-25-0.95.hdf5
# Epoch 26/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1683 - acc: 0.9471 - val_loss: 0.1479 - val_acc: 0.9549
#
# Epoch 00026: val_acc improved from 0.95474 to 0.95491, saving model to /content/gdrive/My Drive/Raajesh-26-0.95.hdf5
# Epoch 27/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1682 - acc: 0.9468 - val_loss: 0.1482 - val_acc: 0.9551
#
# Epoch 00027: val_acc improved from 0.95491 to 0.95506, saving model to /content/gdrive/My Drive/Raajesh-27-0.96.hdf5
# Epoch 28/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1678 - acc: 0.9471 - val_loss: 0.1496 - val_acc: 0.9541
#
# Epoch 00028: val_acc did not improve from 0.95506
# Epoch 29/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1684 - acc: 0.9474 - val_loss: 0.1472 - val_acc: 0.9551
#
# Epoch 00029: val_acc improved from 0.95506 to 0.95514, saving model to /content/gdrive/My Drive/Raajesh-29-0.96.hdf5
# Epoch 30/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1685 - acc: 0.9470 - val_loss: 0.1481 - val_acc: 0.9546
#
# Epoch 00030: val_acc did not improve from 0.95514
# Epoch 31/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1684 - acc: 0.9470 - val_loss: 0.1509 - val_acc: 0.9543
#
# Epoch 00031: val_acc did not improve from 0.95514
# Epoch 32/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1683 - acc: 0.9466 - val_loss: 0.1511 - val_acc: 0.9537
#
# Epoch 00032: val_acc did not improve from 0.95514
# Epoch 33/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1670 - acc: 0.9474 - val_loss: 0.1488 - val_acc: 0.9545
#
# Epoch 00033: val_acc did not improve from 0.95514
# Epoch 34/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1670 - acc: 0.9472 - val_loss: 0.1481 - val_acc: 0.9545
#
# Epoch 00034: val_acc did not improve from 0.95514
# Epoch 35/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1665 - acc: 0.9475 - val_loss: 0.1492 - val_acc: 0.9542
#
# Epoch 00035: val_acc did not improve from 0.95514
# Epoch 36/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1647 - acc: 0.9482 - val_loss: 0.1433 - val_acc: 0.9558
#
# Epoch 00036: val_acc improved from 0.95514 to 0.95585, saving model to /content/gdrive/My Drive/Raajesh-36-0.96.hdf5
# Epoch 37/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1636 - acc: 0.9486 - val_loss: 0.1450 - val_acc: 0.9560
#
# Epoch 00037: val_acc improved from 0.95585 to 0.95601, saving model to /content/gdrive/My Drive/Raajesh-37-0.96.hdf5
# Epoch 38/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1621 - acc: 0.9486 - val_loss: 0.1393 - val_acc: 0.9582
#
# Epoch 00038: val_acc improved from 0.95601 to 0.95818, saving model to /content/gdrive/My Drive/Raajesh-38-0.96.hdf5
# Epoch 39/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1603 - acc: 0.9497 - val_loss: 0.1382 - val_acc: 0.9584
#
# Epoch 00039: val_acc improved from 0.95818 to 0.95840, saving model to /content/gdrive/My Drive/Raajesh-39-0.96.hdf5
# Epoch 40/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1581 - acc: 0.9506 - val_loss: 0.1366 - val_acc: 0.9588
#
# Epoch 00040: val_acc improved from 0.95840 to 0.95882, saving model to /content/gdrive/My Drive/Raajesh-40-0.96.hdf5
# Epoch 41/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1574 - acc: 0.9508 - val_loss: 0.1344 - val_acc: 0.9588
#
# Epoch 00041: val_acc did not improve from 0.95882
# Epoch 42/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1559 - acc: 0.9513 - val_loss: 0.1357 - val_acc: 0.9591
#
# Epoch 00042: val_acc improved from 0.95882 to 0.95907, saving model to /content/gdrive/My Drive/Raajesh-42-0.96.hdf5
# Epoch 43/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1533 - acc: 0.9520 - val_loss: 0.1340 - val_acc: 0.9602
#
# Epoch 00043: val_acc improved from 0.95907 to 0.96020, saving model to /content/gdrive/My Drive/Raajesh-43-0.96.hdf5
# Epoch 44/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1523 - acc: 0.9523 - val_loss: 0.1318 - val_acc: 0.9608
#
# Epoch 00044: val_acc improved from 0.96020 to 0.96076, saving model to /content/gdrive/My Drive/Raajesh-44-0.96.hdf5
# Epoch 45/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1513 - acc: 0.9526 - val_loss: 0.1298 - val_acc: 0.9618
#
# Epoch 00045: val_acc improved from 0.96076 to 0.96180, saving model to /content/gdrive/My Drive/Raajesh-45-0.96.hdf5
# Epoch 46/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1493 - acc: 0.9534 - val_loss: 0.1294 - val_acc: 0.9621
#
# Epoch 00046: val_acc improved from 0.96180 to 0.96213, saving model to /content/gdrive/My Drive/Raajesh-46-0.96.hdf5
# Epoch 47/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1478 - acc: 0.9539 - val_loss: 0.1260 - val_acc: 0.9630
#
# Epoch 00047: val_acc improved from 0.96213 to 0.96300, saving model to /content/gdrive/My Drive/Raajesh-47-0.96.hdf5
# Epoch 48/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1460 - acc: 0.9545 - val_loss: 0.1238 - val_acc: 0.9639
#
# Epoch 00048: val_acc improved from 0.96300 to 0.96389, saving model to /content/gdrive/My Drive/Raajesh-48-0.96.hdf5
# Epoch 49/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1449 - acc: 0.9549 - val_loss: 0.1245 - val_acc: 0.9630
#
# Epoch 00049: val_acc did not improve from 0.96389
# Epoch 50/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1427 - acc: 0.9557 - val_loss: 0.1254 - val_acc: 0.9634
#
# Epoch 00050: val_acc did not improve from 0.96389
# Epoch 51/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1417 - acc: 0.9562 - val_loss: 0.1208 - val_acc: 0.9645
#
# Epoch 00051: val_acc improved from 0.96389 to 0.96450, saving model to /content/gdrive/My Drive/Raajesh-51-0.96.hdf5
# Epoch 52/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1410 - acc: 0.9564 - val_loss: 0.1232 - val_acc: 0.9640
#
# Epoch 00052: val_acc did not improve from 0.96450
# Epoch 53/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1401 - acc: 0.9565 - val_loss: 0.1233 - val_acc: 0.9637
#
# Epoch 00053: val_acc did not improve from 0.96450
# Epoch 54/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1393 - acc: 0.9568 - val_loss: 0.1208 - val_acc: 0.9644
#
# Epoch 00054: val_acc did not improve from 0.96450
# Epoch 55/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1388 - acc: 0.9570 - val_loss: 0.1205 - val_acc: 0.9647
#
# Epoch 00055: val_acc improved from 0.96450 to 0.96471, saving model to /content/gdrive/My Drive/Raajesh-55-0.96.hdf5
# Epoch 56/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1375 - acc: 0.9572 - val_loss: 0.1153 - val_acc: 0.9663
#
# Epoch 00056: val_acc improved from 0.96471 to 0.96628, saving model to /content/gdrive/My Drive/Raajesh-56-0.97.hdf5
# Epoch 57/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1358 - acc: 0.9579 - val_loss: 0.1169 - val_acc: 0.9660
#
# Epoch 00057: val_acc did not improve from 0.96628
# Epoch 58/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1357 - acc: 0.9578 - val_loss: 0.1148 - val_acc: 0.9663
#
# Epoch 00058: val_acc improved from 0.96628 to 0.96632, saving model to /content/gdrive/My Drive/Raajesh-58-0.97.hdf5
# Epoch 59/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1337 - acc: 0.9587 - val_loss: 0.1125 - val_acc: 0.9675
#
# Epoch 00059: val_acc improved from 0.96632 to 0.96746, saving model to /content/gdrive/My Drive/Raajesh-59-0.97.hdf5
# Epoch 60/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1329 - acc: 0.9588 - val_loss: 0.1145 - val_acc: 0.9666
#
# Epoch 00060: val_acc did not improve from 0.96746
# Epoch 61/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1328 - acc: 0.9590 - val_loss: 0.1112 - val_acc: 0.9680
#
# Epoch 00061: val_acc improved from 0.96746 to 0.96796, saving model to /content/gdrive/My Drive/Raajesh-61-0.97.hdf5
# Epoch 62/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1310 - acc: 0.9596 - val_loss: 0.1114 - val_acc: 0.9684
#
# Epoch 00062: val_acc improved from 0.96796 to 0.96838, saving model to /content/gdrive/My Drive/Raajesh-62-0.97.hdf5
# Epoch 63/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1299 - acc: 0.9599 - val_loss: 0.1161 - val_acc: 0.9657
#
# Epoch 00063: val_acc did not improve from 0.96838
# Epoch 64/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1296 - acc: 0.9598 - val_loss: 0.1102 - val_acc: 0.9684
#
# Epoch 00064: val_acc improved from 0.96838 to 0.96841, saving model to /content/gdrive/My Drive/Raajesh-64-0.97.hdf5
# Epoch 65/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1280 - acc: 0.9604 - val_loss: 0.1105 - val_acc: 0.9681
#
# Epoch 00065: val_acc did not improve from 0.96841
# Epoch 66/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1274 - acc: 0.9606 - val_loss: 0.1098 - val_acc: 0.9679
#
# Epoch 00066: val_acc did not improve from 0.96841
# Epoch 67/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1270 - acc: 0.9608 - val_loss: 0.1140 - val_acc: 0.9663
#
# Epoch 00067: val_acc did not improve from 0.96841
# Epoch 68/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1245 - acc: 0.9614 - val_loss: 0.1116 - val_acc: 0.9672
#
# Epoch 00068: val_acc did not improve from 0.96841
# Epoch 69/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1237 - acc: 0.9619 - val_loss: 0.1075 - val_acc: 0.9693
#
# Epoch 00069: val_acc improved from 0.96841 to 0.96925, saving model to /content/gdrive/My Drive/Raajesh-69-0.97.hdf5
# Epoch 70/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1236 - acc: 0.9620 - val_loss: 0.1067 - val_acc: 0.9692
#
# Epoch 00070: val_acc did not improve from 0.96925
# Epoch 71/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1227 - acc: 0.9621 - val_loss: 0.1087 - val_acc: 0.9688
#
# Epoch 00071: val_acc did not improve from 0.96925
# Epoch 72/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1214 - acc: 0.9628 - val_loss: 0.1068 - val_acc: 0.9694
#
# Epoch 00072: val_acc improved from 0.96925 to 0.96936, saving model to /content/gdrive/My Drive/Raajesh-72-0.97.hdf5
# Epoch 73/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1211 - acc: 0.9622 - val_loss: 0.1018 - val_acc: 0.9709
#
# Epoch 00073: val_acc improved from 0.96936 to 0.97094, saving model to /content/gdrive/My Drive/Raajesh-73-0.97.hdf5
# Epoch 74/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1199 - acc: 0.9629 - val_loss: 0.1028 - val_acc: 0.9710
#
# Epoch 00074: val_acc improved from 0.97094 to 0.97102, saving model to /content/gdrive/My Drive/Raajesh-74-0.97.hdf5
# Epoch 75/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1194 - acc: 0.9631 - val_loss: 0.1043 - val_acc: 0.9696
#
# Epoch 00075: val_acc did not improve from 0.97102
# Epoch 76/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1188 - acc: 0.9633 - val_loss: 0.1016 - val_acc: 0.9709
#
# Epoch 00076: val_acc did not improve from 0.97102
# Epoch 77/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1182 - acc: 0.9635 - val_loss: 0.1014 - val_acc: 0.9715
#
# Epoch 00077: val_acc improved from 0.97102 to 0.97148, saving model to /content/gdrive/My Drive/Raajesh-77-0.97.hdf5
# Epoch 78/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1168 - acc: 0.9643 - val_loss: 0.0986 - val_acc: 0.9719
#
# Epoch 00078: val_acc improved from 0.97148 to 0.97193, saving model to /content/gdrive/My Drive/Raajesh-78-0.97.hdf5
# Epoch 79/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1173 - acc: 0.9637 - val_loss: 0.1053 - val_acc: 0.9692
#
# Epoch 00079: val_acc did not improve from 0.97193
# Epoch 80/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1163 - acc: 0.9641 - val_loss: 0.1023 - val_acc: 0.9712
#
# Epoch 00080: val_acc did not improve from 0.97193
# Epoch 81/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1152 - acc: 0.9645 - val_loss: 0.1011 - val_acc: 0.9709
#
# Epoch 00081: val_acc did not improve from 0.97193
# Epoch 82/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1147 - acc: 0.9645 - val_loss: 0.0991 - val_acc: 0.9717
#
# Epoch 00082: val_acc did not improve from 0.97193
# Epoch 83/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1125 - acc: 0.9656 - val_loss: 0.1001 - val_acc: 0.9716
#
# Epoch 00083: val_acc did not improve from 0.97193
# Epoch 84/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1126 - acc: 0.9653 - val_loss: 0.1031 - val_acc: 0.9707
#
# Epoch 00084: val_acc did not improve from 0.97193
# Epoch 85/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1114 - acc: 0.9658 - val_loss: 0.0960 - val_acc: 0.9725
#
# Epoch 00085: val_acc improved from 0.97193 to 0.97251, saving model to /content/gdrive/My Drive/Raajesh-85-0.97.hdf5
# Epoch 86/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1096 - acc: 0.9665 - val_loss: 0.0991 - val_acc: 0.9719
#
# Epoch 00086: val_acc did not improve from 0.97251
# Epoch 87/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1108 - acc: 0.9659 - val_loss: 0.0936 - val_acc: 0.9732
#
# Epoch 00087: val_acc improved from 0.97251 to 0.97324, saving model to /content/gdrive/My Drive/Raajesh-87-0.97.hdf5
# Epoch 88/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1099 - acc: 0.9663 - val_loss: 0.0956 - val_acc: 0.9731
#
# Epoch 00088: val_acc did not improve from 0.97324
# Epoch 89/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1099 - acc: 0.9662 - val_loss: 0.0971 - val_acc: 0.9726
#
# Epoch 00089: val_acc did not improve from 0.97324
# Epoch 90/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1086 - acc: 0.9667 - val_loss: 0.0926 - val_acc: 0.9737
#
# Epoch 00090: val_acc improved from 0.97324 to 0.97371, saving model to /content/gdrive/My Drive/Raajesh-90-0.97.hdf5
# Epoch 91/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1096 - acc: 0.9661 - val_loss: 0.0957 - val_acc: 0.9730
#
# Epoch 00091: val_acc did not improve from 0.97371
# Epoch 92/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1084 - acc: 0.9664 - val_loss: 0.0961 - val_acc: 0.9727
#
# Epoch 00092: val_acc did not improve from 0.97371
# Epoch 93/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1075 - acc: 0.9671 - val_loss: 0.0942 - val_acc: 0.9733
#
# Epoch 00093: val_acc did not improve from 0.97371
# Epoch 94/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1077 - acc: 0.9668 - val_loss: 0.0925 - val_acc: 0.9743
#
# Epoch 00094: val_acc improved from 0.97371 to 0.97425, saving model to /content/gdrive/My Drive/Raajesh-94-0.97.hdf5
# Epoch 95/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1070 - acc: 0.9671 - val_loss: 0.0943 - val_acc: 0.9728
#
# Epoch 00095: val_acc did not improve from 0.97425
# Epoch 96/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1053 - acc: 0.9675 - val_loss: 0.0937 - val_acc: 0.9734
#
# Epoch 00096: val_acc did not improve from 0.97425
# Epoch 97/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1055 - acc: 0.9678 - val_loss: 0.0938 - val_acc: 0.9727
#
# Epoch 00097: val_acc did not improve from 0.97425
# Epoch 98/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1046 - acc: 0.9679 - val_loss: 0.0920 - val_acc: 0.9738
#
# Epoch 00098: val_acc did not improve from 0.97425
# Epoch 99/100
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1041 - acc: 0.9678 - val_loss: 0.0906 - val_acc: 0.9742
#
# Epoch 00099: val_acc did not improve from 0.97425
# Epoch 100/100
# 391/391 [==============================] - 29s 73ms/step - loss: 0.1031 - acc: 0.9682 - val_loss: 0.0907 - val_acc: 0.9737
#
# Epoch 00100: val_acc did not improve from 0.97425

# %%
model1.load_weights('/content/gdrive/My Drive/Raajesh-94-0.97.hdf5')

# %%
score = model1.evaluate_generator(test_generator,steps=np.ceil(10000/128))
print(score)
# Out:
# [0.09249678500890732, 0.9742500058174133]

# %%
count = model1.predict_generator(test_generator,np.ceil(10000/128))
print(count.shape)
# Out:
# (10000, 10)

# %%
(Train_features, Train_labels),(Test_features,Test_labels) = cifar10.load_data()
train_features = train_features.astype('float32')/255
Test_features = Test_features.astype('float32')/255
predicted_classes = model1.predict_classes(Test_features)
Test_labels = Test_labels.reshape(10000,)
incorrect = np.nonzero(predicted_classes!=Test_labels)
arincorr = incorrect[0][0:25]

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.figure(0)
plt.figure(figsize = (25,25)) 
plots = []
count = 0
for i in range(5):
    for j in range(5):
        ax = plt.subplot2grid((5,5), (i,j))
        #print(arcorr[count])
        plt.imshow(Test_features[arincorr[count]].reshape(32,32,3),cmap='gray',interpolation='none')
        true = int(Test_labels[arincorr[count]])
        pred = int(predicted_classes[arincorr[count]])
        plt.title("True Class: "+str(class_names[true])+" Pred Class: " +str(class_names[pred]))
        #plt.title("Predicted {}, Class {}".format(predicted_classes[arcorr[count]], Test_labels[arcorr[count]]))
        count = count+1
plt.show()

# %%
(Train_features, Train_labels),(Test_features,Test_labels) = cifar10.load_data()

# %%
Train_features = Train_features.astype('float32')/255
Test_features = Test_features.astype('float32')/255

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
for n in arincorr:
  gradcam(n)

# %%
def gradcam(image_number):
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
  test_features = test_features.astype('float32')/255
  test_labels = np_utils.to_categorical(test_labels, num_classes)  
  img = test_features[image_number]
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  #x = preprocess_input(x)  
  preds = model1.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model1.output[:, class_idx]
  last_conv_layer = model1.get_layer("conv2d_8") 
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model1.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(256):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)  
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()  
  img = test_features[image_number]
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  #from google.colab.patches import cv2_imshow
  img = cv2.resize(img,(224,224))
  superimposed_img = cv2.resize(superimposed_img,(224,224))
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  #cv2.waitKey(0)
  con = np.concatenate((img, superimposed_img), axis = 0)
  true = int(Test_labels[image_number])
  pred = int(predicted_classes[image_number])
  plt.title("True Class: " + str(class_names[true])+"    Pred Class: " + str(class_names[pred]))
  plt.imshow(con)
  plt.show()
  #plt.imshow(superimposed_img)
  #plt.title("predicted :",str(labels[predicted_classes[127]]))
  plt.axis('off')
  #plt.title("Predicted : " + labels[predicted_classes[image_number]], "True class : " + str(labels[Test_labels[image_number]])
  #plt.show()
  #cv2.waitKey(0)
