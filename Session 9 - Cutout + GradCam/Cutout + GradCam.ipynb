# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import SpatialDropout2D
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
Train_labels = np_utils.to_categorical(train_labels, num_classes)
Test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# #### NETWORK WITH OUT CUTOUT

# %%
model = Sequential()
model.add(Convolution2D(96, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(BatchNormalization())
model.add(Convolution2D(192, 3, 3, border_mode='same',activation='relu'))
model.add(Dropout(0.25))
        
model.add(Convolution2D(48, 1, 1,border_mode='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
          
model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same',activation='relu'))
model.add(Dropout(0.25))

model.add(BatchNormalization())
model.add(Convolution2D(192, 3, 3, border_mode='same',activation='relu'))
model.add(Dropout(0.25))

model.add(Convolution2D(48, 1, 1,border_mode='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same',activation='relu'))
model.add(Dropout(0.25))

model.add(BatchNormalization())
model.add(Convolution2D(192, 3, 3, border_mode='same',activation='relu'))
model.add(Dropout(0.25))

model.add(Convolution2D(10, 8, 8))
model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0708 16:47:51.344166 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# W0708 16:47:51.367820 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0708 16:47:51.371638 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0708 16:47:51.410352 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0708 16:47:51.411741 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0708 16:47:52.011324 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0708 16:47:52.224194 140291398506368 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), activation="relu", padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", padding="same")`
#   # This is added back by InteractiveShellApp.init_path()
# W0708 16:47:52.400253 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), activation="relu", padding="same")`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`
# W0708 16:47:53.000839 140291398506368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 96)        2688
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 96)        384
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 96)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 96)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 96)        384
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 192)       166080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 192)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 48)        9264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 48)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 96)        41568
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 96)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 192)       166080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 192)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 48)        9264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 48)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 96)          41568
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 96)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 96)          384
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 192)         166080
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 10)          122890
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 727,402
# Trainable params: 726,442
# Non-trainable params: 960
# _________________________________________________________________

# %%
# For retrieving the saved best results
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Defining checkpoints
from keras.callbacks import ModelCheckpoint
filepath="/content/gdrive/My Drive/Raajesh-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# #### NO CUTOUT

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, Train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, Test_labels), verbose=1, callbacks=callbacks_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, Test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 37s 95ms/step - loss: 1.4853 - acc: 0.4824 - val_loss: 1.3104 - val_acc: 0.5366
#
# Epoch 00001: val_acc improved from -inf to 0.53660, saving model to /content/gdrive/My Drive/Raajesh-01-0.54.hdf5
# Epoch 2/100
# 390/390 [==============================] - 35s 90ms/step - loss: 0.9652 - acc: 0.6565 - val_loss: 1.0314 - val_acc: 0.6320
#
# Epoch 00002: val_acc improved from 0.53660 to 0.63200, saving model to /content/gdrive/My Drive/Raajesh-02-0.63.hdf5
# Epoch 3/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.7678 - acc: 0.7292 - val_loss: 0.9154 - val_acc: 0.6794
#
# Epoch 00003: val_acc improved from 0.63200 to 0.67940, saving model to /content/gdrive/My Drive/Raajesh-03-0.68.hdf5
# Epoch 4/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.6532 - acc: 0.7717 - val_loss: 0.7478 - val_acc: 0.7385
#
# Epoch 00004: val_acc improved from 0.67940 to 0.73850, saving model to /content/gdrive/My Drive/Raajesh-04-0.74.hdf5
# Epoch 5/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5724 - acc: 0.7995 - val_loss: 0.7738 - val_acc: 0.7352
#
# Epoch 00005: val_acc did not improve from 0.73850
# Epoch 6/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5133 - acc: 0.8189 - val_loss: 0.6878 - val_acc: 0.7635
#
# Epoch 00006: val_acc improved from 0.73850 to 0.76350, saving model to /content/gdrive/My Drive/Raajesh-06-0.76.hdf5
# Epoch 7/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4675 - acc: 0.8364 - val_loss: 0.7200 - val_acc: 0.7536
#
# Epoch 00007: val_acc did not improve from 0.76350
# Epoch 8/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4292 - acc: 0.8501 - val_loss: 0.6717 - val_acc: 0.7734
#
# Epoch 00008: val_acc improved from 0.76350 to 0.77340, saving model to /content/gdrive/My Drive/Raajesh-08-0.77.hdf5
# Epoch 9/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3932 - acc: 0.8606 - val_loss: 0.6102 - val_acc: 0.7890
#
# Epoch 00009: val_acc improved from 0.77340 to 0.78900, saving model to /content/gdrive/My Drive/Raajesh-09-0.79.hdf5
# Epoch 10/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3699 - acc: 0.8693 - val_loss: 0.6111 - val_acc: 0.7988
#
# Epoch 00010: val_acc improved from 0.78900 to 0.79880, saving model to /content/gdrive/My Drive/Raajesh-10-0.80.hdf5
# Epoch 11/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3428 - acc: 0.8775 - val_loss: 0.7666 - val_acc: 0.7550
#
# Epoch 00011: val_acc did not improve from 0.79880
# Epoch 12/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3137 - acc: 0.8882 - val_loss: 0.6511 - val_acc: 0.7846
#
# Epoch 00012: val_acc did not improve from 0.79880
# Epoch 13/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3031 - acc: 0.8916 - val_loss: 0.6228 - val_acc: 0.8005
#
# Epoch 00013: val_acc improved from 0.79880 to 0.80050, saving model to /content/gdrive/My Drive/Raajesh-13-0.80.hdf5
# Epoch 14/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2862 - acc: 0.8977 - val_loss: 0.6584 - val_acc: 0.7980
#
# Epoch 00014: val_acc did not improve from 0.80050
# Epoch 15/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2675 - acc: 0.9026 - val_loss: 0.6026 - val_acc: 0.8067
#
# Epoch 00015: val_acc improved from 0.80050 to 0.80670, saving model to /content/gdrive/My Drive/Raajesh-15-0.81.hdf5
# Epoch 16/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2531 - acc: 0.9090 - val_loss: 0.6833 - val_acc: 0.7969
#
# Epoch 00016: val_acc did not improve from 0.80670
# Epoch 17/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2434 - acc: 0.9131 - val_loss: 0.6069 - val_acc: 0.8063
#
# Epoch 00017: val_acc did not improve from 0.80670
# Epoch 18/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2262 - acc: 0.9186 - val_loss: 0.6764 - val_acc: 0.7912
#
# Epoch 00018: val_acc did not improve from 0.80670
# Epoch 19/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2231 - acc: 0.9202 - val_loss: 0.7188 - val_acc: 0.7917
#
# Epoch 00019: val_acc did not improve from 0.80670
# Epoch 20/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2103 - acc: 0.9237 - val_loss: 0.6210 - val_acc: 0.8145
#
# Epoch 00020: val_acc improved from 0.80670 to 0.81450, saving model to /content/gdrive/My Drive/Raajesh-20-0.81.hdf5
# Epoch 21/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2090 - acc: 0.9252 - val_loss: 0.5866 - val_acc: 0.8189
#
# Epoch 00021: val_acc improved from 0.81450 to 0.81890, saving model to /content/gdrive/My Drive/Raajesh-21-0.82.hdf5
# Epoch 22/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1941 - acc: 0.9304 - val_loss: 0.6052 - val_acc: 0.8172
#
# Epoch 00022: val_acc did not improve from 0.81890
# Epoch 23/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1893 - acc: 0.9336 - val_loss: 0.6131 - val_acc: 0.8205
#
# Epoch 00023: val_acc improved from 0.81890 to 0.82050, saving model to /content/gdrive/My Drive/Raajesh-23-0.82.hdf5
# Epoch 24/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1834 - acc: 0.9348 - val_loss: 0.6407 - val_acc: 0.8056
#
# Epoch 00024: val_acc did not improve from 0.82050
# Epoch 25/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1815 - acc: 0.9356 - val_loss: 0.6502 - val_acc: 0.8090
#
# Epoch 00025: val_acc did not improve from 0.82050
# Epoch 26/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1675 - acc: 0.9403 - val_loss: 0.6139 - val_acc: 0.8218
#
# Epoch 00026: val_acc improved from 0.82050 to 0.82180, saving model to /content/gdrive/My Drive/Raajesh-26-0.82.hdf5
# Epoch 27/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1684 - acc: 0.9399 - val_loss: 0.6065 - val_acc: 0.8237
#
# Epoch 00027: val_acc improved from 0.82180 to 0.82370, saving model to /content/gdrive/My Drive/Raajesh-27-0.82.hdf5
# Epoch 28/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1680 - acc: 0.9399 - val_loss: 0.6388 - val_acc: 0.8166
#
# Epoch 00028: val_acc did not improve from 0.82370
# Epoch 29/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1606 - acc: 0.9428 - val_loss: 0.6289 - val_acc: 0.8204
#
# Epoch 00029: val_acc did not improve from 0.82370
# Epoch 30/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1569 - acc: 0.9441 - val_loss: 0.6603 - val_acc: 0.8165
#
# Epoch 00030: val_acc did not improve from 0.82370
# Epoch 31/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1498 - acc: 0.9464 - val_loss: 0.6632 - val_acc: 0.8129
#
# Epoch 00031: val_acc did not improve from 0.82370
# Epoch 32/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1476 - acc: 0.9483 - val_loss: 0.6382 - val_acc: 0.8229
#
# Epoch 00032: val_acc did not improve from 0.82370
# Epoch 33/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1426 - acc: 0.9494 - val_loss: 0.7014 - val_acc: 0.8112
#
# Epoch 00033: val_acc did not improve from 0.82370
# Epoch 34/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1361 - acc: 0.9534 - val_loss: 0.6513 - val_acc: 0.8205
#
# Epoch 00034: val_acc did not improve from 0.82370
# Epoch 35/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1337 - acc: 0.9520 - val_loss: 0.6999 - val_acc: 0.8099
#
# Epoch 00035: val_acc did not improve from 0.82370
# Epoch 36/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1371 - acc: 0.9519 - val_loss: 0.5865 - val_acc: 0.8368
#
# Epoch 00036: val_acc improved from 0.82370 to 0.83680, saving model to /content/gdrive/My Drive/Raajesh-36-0.84.hdf5
# Epoch 37/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1287 - acc: 0.9541 - val_loss: 0.6904 - val_acc: 0.8188
#
# Epoch 00037: val_acc did not improve from 0.83680
# Epoch 38/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1273 - acc: 0.9545 - val_loss: 0.6464 - val_acc: 0.8275
#
# Epoch 00038: val_acc did not improve from 0.83680
# Epoch 39/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1278 - acc: 0.9544 - val_loss: 0.6587 - val_acc: 0.8248
#
# Epoch 00039: val_acc did not improve from 0.83680
# Epoch 40/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1242 - acc: 0.9572 - val_loss: 0.6381 - val_acc: 0.8217
#
# Epoch 00040: val_acc did not improve from 0.83680
# Epoch 41/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1209 - acc: 0.9577 - val_loss: 0.6666 - val_acc: 0.8276
#
# Epoch 00041: val_acc did not improve from 0.83680
# Epoch 42/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1193 - acc: 0.9587 - val_loss: 0.6716 - val_acc: 0.8246
#
# Epoch 00042: val_acc did not improve from 0.83680
# Epoch 43/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1176 - acc: 0.9583 - val_loss: 0.6111 - val_acc: 0.8266
#
# Epoch 00043: val_acc did not improve from 0.83680
# Epoch 44/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1138 - acc: 0.9595 - val_loss: 0.6411 - val_acc: 0.8279
#
# Epoch 00044: val_acc did not improve from 0.83680
# Epoch 45/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1132 - acc: 0.9595 - val_loss: 0.6916 - val_acc: 0.8383
#
# Epoch 00045: val_acc improved from 0.83680 to 0.83830, saving model to /content/gdrive/My Drive/Raajesh-45-0.84.hdf5
# Epoch 46/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1085 - acc: 0.9623 - val_loss: 0.6721 - val_acc: 0.8264
#
# Epoch 00046: val_acc did not improve from 0.83830
# Epoch 47/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1075 - acc: 0.9610 - val_loss: 0.6068 - val_acc: 0.8331
#
# Epoch 00047: val_acc did not improve from 0.83830
# Epoch 48/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1051 - acc: 0.9627 - val_loss: 0.6425 - val_acc: 0.8284
#
# Epoch 00048: val_acc did not improve from 0.83830
# Epoch 49/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1045 - acc: 0.9636 - val_loss: 0.6258 - val_acc: 0.8362
#
# Epoch 00049: val_acc did not improve from 0.83830
# Epoch 50/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1059 - acc: 0.9630 - val_loss: 0.6482 - val_acc: 0.8338
#
# Epoch 00050: val_acc did not improve from 0.83830
# Epoch 51/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0986 - acc: 0.9658 - val_loss: 0.7227 - val_acc: 0.8293
#
# Epoch 00051: val_acc did not improve from 0.83830
# Epoch 52/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0998 - acc: 0.9645 - val_loss: 0.6584 - val_acc: 0.8332
#
# Epoch 00052: val_acc did not improve from 0.83830
# Epoch 53/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0987 - acc: 0.9653 - val_loss: 0.6489 - val_acc: 0.8387
#
# Epoch 00053: val_acc improved from 0.83830 to 0.83870, saving model to /content/gdrive/My Drive/Raajesh-53-0.84.hdf5
# Epoch 54/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0995 - acc: 0.9648 - val_loss: 0.6205 - val_acc: 0.8375
#
# Epoch 00054: val_acc did not improve from 0.83870
# Epoch 55/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0964 - acc: 0.9657 - val_loss: 0.6409 - val_acc: 0.8355
#
# Epoch 00055: val_acc did not improve from 0.83870
# Epoch 56/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0947 - acc: 0.9663 - val_loss: 0.6505 - val_acc: 0.8420
#
# Epoch 00056: val_acc improved from 0.83870 to 0.84200, saving model to /content/gdrive/My Drive/Raajesh-56-0.84.hdf5
# Epoch 57/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0888 - acc: 0.9692 - val_loss: 0.6543 - val_acc: 0.8380
#
# Epoch 00057: val_acc did not improve from 0.84200
# Epoch 58/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0876 - acc: 0.9685 - val_loss: 0.6527 - val_acc: 0.8363
#
# Epoch 00058: val_acc did not improve from 0.84200
# Epoch 59/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0917 - acc: 0.9671 - val_loss: 0.6178 - val_acc: 0.8376
#
# Epoch 00059: val_acc did not improve from 0.84200
# Epoch 60/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0886 - acc: 0.9683 - val_loss: 0.6209 - val_acc: 0.8420
#
# Epoch 00060: val_acc did not improve from 0.84200
# Epoch 61/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0847 - acc: 0.9706 - val_loss: 0.6841 - val_acc: 0.8371
#
# Epoch 00061: val_acc did not improve from 0.84200
# Epoch 62/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0857 - acc: 0.9695 - val_loss: 0.6749 - val_acc: 0.8365
#
# Epoch 00062: val_acc did not improve from 0.84200
# Epoch 63/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0863 - acc: 0.9702 - val_loss: 0.7260 - val_acc: 0.8258
#
# Epoch 00063: val_acc did not improve from 0.84200
# Epoch 64/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0840 - acc: 0.9711 - val_loss: 0.6549 - val_acc: 0.8348
#
# Epoch 00064: val_acc did not improve from 0.84200
# Epoch 65/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0815 - acc: 0.9708 - val_loss: 0.6998 - val_acc: 0.8335
#
# Epoch 00065: val_acc did not improve from 0.84200
# Epoch 66/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0791 - acc: 0.9719 - val_loss: 0.6600 - val_acc: 0.8465
#
# Epoch 00066: val_acc improved from 0.84200 to 0.84650, saving model to /content/gdrive/My Drive/Raajesh-66-0.85.hdf5
# Epoch 67/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0805 - acc: 0.9714 - val_loss: 0.6940 - val_acc: 0.8333
#
# Epoch 00067: val_acc did not improve from 0.84650
# Epoch 68/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0775 - acc: 0.9737 - val_loss: 0.6704 - val_acc: 0.8392
#
# Epoch 00068: val_acc did not improve from 0.84650
# Epoch 69/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0804 - acc: 0.9722 - val_loss: 0.6518 - val_acc: 0.8280
#
# Epoch 00069: val_acc did not improve from 0.84650
# Epoch 70/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0773 - acc: 0.9727 - val_loss: 0.6141 - val_acc: 0.8394
#
# Epoch 00070: val_acc did not improve from 0.84650
# Epoch 71/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0779 - acc: 0.9736 - val_loss: 0.6525 - val_acc: 0.8412
#
# Epoch 00071: val_acc did not improve from 0.84650
# Epoch 72/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0730 - acc: 0.9744 - val_loss: 0.6768 - val_acc: 0.8369
#
# Epoch 00072: val_acc did not improve from 0.84650
# Epoch 73/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0739 - acc: 0.9739 - val_loss: 0.6407 - val_acc: 0.8448
#
# Epoch 00073: val_acc did not improve from 0.84650
# Epoch 74/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0717 - acc: 0.9743 - val_loss: 0.6445 - val_acc: 0.8468
#
# Epoch 00074: val_acc improved from 0.84650 to 0.84680, saving model to /content/gdrive/My Drive/Raajesh-74-0.85.hdf5
# Epoch 75/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0778 - acc: 0.9727 - val_loss: 0.6746 - val_acc: 0.8396
#
# Epoch 00075: val_acc did not improve from 0.84680
# Epoch 76/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0741 - acc: 0.9736 - val_loss: 0.6649 - val_acc: 0.8387
#
# Epoch 00076: val_acc did not improve from 0.84680
# Epoch 77/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0740 - acc: 0.9740 - val_loss: 0.6820 - val_acc: 0.8416
#
# Epoch 00077: val_acc did not improve from 0.84680
# Epoch 78/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0718 - acc: 0.9754 - val_loss: 0.6298 - val_acc: 0.8437
#
# Epoch 00078: val_acc did not improve from 0.84680
# Epoch 79/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0760 - acc: 0.9734 - val_loss: 0.6791 - val_acc: 0.8383
#
# Epoch 00079: val_acc did not improve from 0.84680
# Epoch 80/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0698 - acc: 0.9750 - val_loss: 0.6219 - val_acc: 0.8478
#
# Epoch 00080: val_acc improved from 0.84680 to 0.84780, saving model to /content/gdrive/My Drive/Raajesh-80-0.85.hdf5
# Epoch 81/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0684 - acc: 0.9761 - val_loss: 0.6417 - val_acc: 0.8477
#
# Epoch 00081: val_acc did not improve from 0.84780
# Epoch 82/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0676 - acc: 0.9762 - val_loss: 0.6606 - val_acc: 0.8446
#
# Epoch 00082: val_acc did not improve from 0.84780
# Epoch 83/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0699 - acc: 0.9750 - val_loss: 0.6444 - val_acc: 0.8445
#
# Epoch 00083: val_acc did not improve from 0.84780
# Epoch 84/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0675 - acc: 0.9763 - val_loss: 0.6605 - val_acc: 0.8439
#
# Epoch 00084: val_acc did not improve from 0.84780
# Epoch 85/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0662 - acc: 0.9776 - val_loss: 0.6767 - val_acc: 0.8375
#
# Epoch 00085: val_acc did not improve from 0.84780
# Epoch 86/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0672 - acc: 0.9769 - val_loss: 0.6466 - val_acc: 0.8473
#
# Epoch 00086: val_acc did not improve from 0.84780
# Epoch 87/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0694 - acc: 0.9756 - val_loss: 0.6890 - val_acc: 0.8391
#
# Epoch 00087: val_acc did not improve from 0.84780
# Epoch 88/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0648 - acc: 0.9775 - val_loss: 0.6420 - val_acc: 0.8457
#
# Epoch 00088: val_acc did not improve from 0.84780
# Epoch 89/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0622 - acc: 0.9776 - val_loss: 0.6047 - val_acc: 0.8433
#
# Epoch 00089: val_acc did not improve from 0.84780
# Epoch 90/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0634 - acc: 0.9779 - val_loss: 0.6360 - val_acc: 0.8501
#
# Epoch 00090: val_acc improved from 0.84780 to 0.85010, saving model to /content/gdrive/My Drive/Raajesh-90-0.85.hdf5
# Epoch 91/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0673 - acc: 0.9762 - val_loss: 0.6368 - val_acc: 0.8428
#
# Epoch 00091: val_acc did not improve from 0.85010
# Epoch 92/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0632 - acc: 0.9780 - val_loss: 0.6452 - val_acc: 0.8451
#
# Epoch 00092: val_acc did not improve from 0.85010
# Epoch 93/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0597 - acc: 0.9794 - val_loss: 0.6436 - val_acc: 0.8467
#
# Epoch 00093: val_acc did not improve from 0.85010
# Epoch 94/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0600 - acc: 0.9795 - val_loss: 0.6657 - val_acc: 0.8457
#
# Epoch 00094: val_acc did not improve from 0.85010
# Epoch 95/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0593 - acc: 0.9790 - val_loss: 0.6635 - val_acc: 0.8358
#
# Epoch 00095: val_acc did not improve from 0.85010
# Epoch 96/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0634 - acc: 0.9777 - val_loss: 0.7142 - val_acc: 0.8450
#
# Epoch 00096: val_acc did not improve from 0.85010
# Epoch 97/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0619 - acc: 0.9783 - val_loss: 0.6420 - val_acc: 0.8458
#
# Epoch 00097: val_acc did not improve from 0.85010
# Epoch 98/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.0629 - acc: 0.9775 - val_loss: 0.6760 - val_acc: 0.8433
#
# Epoch 00098: val_acc did not improve from 0.85010
# Epoch 99/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0608 - acc: 0.9785 - val_loss: 0.6482 - val_acc: 0.8437
#
# Epoch 00099: val_acc did not improve from 0.85010
# Epoch 100/100
# 390/390 [==============================] - 34s 87ms/step - loss: 0.0585 - acc: 0.9793 - val_loss: 0.6967 - val_acc: 0.8396
#
# Epoch 00100: val_acc did not improve from 0.85010
# Model took 3434.57 seconds to train
# Accuracy on test data is: 83.96

# %%
model.load_weights('/content/gdrive/My Drive/Raajesh-90-0.85.hdf5')

# %% [markdown]
# #### FINDING CORRECTLY CLASSIFIED IMAGES TO USE FOR GRADCAM

# %%
(Train_features, Train_labels),(Test_features,Test_labels) = cifar10.load_data()
train_features = train_features.astype('float32')/255
Test_features = Test_features.astype('float32')/255
predicted_classes = model.predict_classes(Test_features)
Test_labels = Test_labels.reshape(10000,)
correct = np.nonzero(predicted_classes==Test_labels)
arcorr = correct[0][0:25]

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.figure(0)
plt.figure(figsize = (25,25)) 
plots = []
count = 0
for i in range(5):
    for j in range(5):
        ax = plt.subplot2grid((5,5), (i,j))
        #print(arcorr[count])
        plt.imshow(Test_features[arcorr[count]].reshape(32,32,3),cmap='gray',interpolation='none')
        true = int(Test_labels[arcorr[count]])
        pred = int(predicted_classes[arcorr[count]])
        plt.title("True Class: "+str(class_names[true])+" Pred Class: " +str(class_names[pred]))
        #plt.title("Predicted {}, Class {}".format(predicted_classes[arcorr[count]], Test_labels[arcorr[count]]))
        count = count+1
plt.show()

# %% [markdown]
# #### USING GRADCAM TO VIEW 4 MISCLASSIFIED IMAGES.

# %%
(Train_features, Train_labels),(Test_features,Test_labels) = cifar10.load_data()

# %%
Train_features = Train_features.astype('float32')/255
Test_features = Test_features.astype('float32')/255

# %%
classified_array =  [127,8,39,84]

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
for n in classified_array:
  gradcam(n)

# %%
def gradcam(image_number):
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
  test_features = test_features.astype('float32')/255
  test_labels = np_utils.to_categorical(test_labels, num_classes)  
  img = test_features[image_number]
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  #x = preprocess_input(x)  
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_8") 
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(192):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)  
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()  
  img = test_features[image_number]
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  #from google.colab.patches import cv2_imshow
  img = cv2.resize(img,(224,224))
  superimposed_img = cv2.resize(superimposed_img,(224,224))
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  #cv2.waitKey(0)
  con = np.concatenate((img, superimposed_img), axis = 0)
  true = int(Test_labels[image_number])
  pred = int(predicted_classes[image_number])
  plt.title("True Class: " + str(class_names[true])+"    Pred Class: " + str(class_names[pred]))
  plt.imshow(con)
  plt.show()
  #plt.imshow(superimposed_img)
  #plt.title("predicted :",str(labels[predicted_classes[127]]))
  plt.axis('off')
  #plt.title("Predicted : " + labels[predicted_classes[image_number]], "True class : " + str(labels[Test_labels[image_number]])
  #plt.show()
  #cv2.waitKey(0)

# %% [markdown]
# #### WITH CUTOUT

# %%
# !wget https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
from random_eraser import get_random_eraser
# Out:
# --2019-07-08 16:49:21--  https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888 [text/plain]
# Saving to: ‘random_eraser.py.1’
#
# random_eraser.py.1  100%[===================>]     888  --.-KB/s    in 0s
#
# 2019-07-08 16:49:21 (123 MB/s) - ‘random_eraser.py.1’ saved [888/888]

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
Train_labels = np_utils.to_categorical(train_labels, num_classes)
Test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False,preprocessing_function=get_random_eraser(v_l=0, v_h=1))

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, Train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, Test_labels), verbose=1, callbacks=callbacks_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, Test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   # This is added back by InteractiveShellApp.init_path()
# W0625 03:55:59.871292 140118683633536 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 39s 99ms/step - loss: 1.6182 - acc: 0.4286 - val_loss: 1.2943 - val_acc: 0.5450
#
# Epoch 00001: val_acc improved from -inf to 0.54500, saving model to /content/gdrive/My Drive/Raajesh-01-0.55.hdf5
# Epoch 2/100
# 390/390 [==============================] - 35s 90ms/step - loss: 1.1044 - acc: 0.6093 - val_loss: 0.9694 - val_acc: 0.6574
#
# Epoch 00002: val_acc improved from 0.54500 to 0.65740, saving model to /content/gdrive/My Drive/Raajesh-02-0.66.hdf5
# Epoch 3/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.9097 - acc: 0.6812 - val_loss: 0.9062 - val_acc: 0.6906
#
# Epoch 00003: val_acc improved from 0.65740 to 0.69060, saving model to /content/gdrive/My Drive/Raajesh-03-0.69.hdf5
# Epoch 4/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.8043 - acc: 0.7175 - val_loss: 0.7628 - val_acc: 0.7337
#
# Epoch 00004: val_acc improved from 0.69060 to 0.73370, saving model to /content/gdrive/My Drive/Raajesh-04-0.73.hdf5
# Epoch 5/100
# 390/390 [==============================] - 35s 90ms/step - loss: 0.7246 - acc: 0.7469 - val_loss: 0.7075 - val_acc: 0.7535
#
# Epoch 00005: val_acc improved from 0.73370 to 0.75350, saving model to /content/gdrive/My Drive/Raajesh-05-0.75.hdf5
# Epoch 6/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.6699 - acc: 0.7666 - val_loss: 0.7014 - val_acc: 0.7563
#
# Epoch 00006: val_acc improved from 0.75350 to 0.75630, saving model to /content/gdrive/My Drive/Raajesh-06-0.76.hdf5
# Epoch 7/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.6283 - acc: 0.7801 - val_loss: 0.7373 - val_acc: 0.7566
#
# Epoch 00007: val_acc improved from 0.75630 to 0.75660, saving model to /content/gdrive/My Drive/Raajesh-07-0.76.hdf5
# Epoch 8/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.5856 - acc: 0.7952 - val_loss: 0.7148 - val_acc: 0.7532
#
# Epoch 00008: val_acc did not improve from 0.75660
# Epoch 9/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.5643 - acc: 0.8010 - val_loss: 0.5875 - val_acc: 0.7992
#
# Epoch 00009: val_acc improved from 0.75660 to 0.79920, saving model to /content/gdrive/My Drive/Raajesh-09-0.80.hdf5
# Epoch 10/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.5370 - acc: 0.8107 - val_loss: 0.6609 - val_acc: 0.7714
#
# Epoch 00010: val_acc did not improve from 0.79920
# Epoch 11/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.5057 - acc: 0.8226 - val_loss: 0.5998 - val_acc: 0.7971
#
# Epoch 00011: val_acc did not improve from 0.79920
# Epoch 12/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4782 - acc: 0.8318 - val_loss: 0.6242 - val_acc: 0.7870
#
# Epoch 00012: val_acc did not improve from 0.79920
# Epoch 13/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4620 - acc: 0.8372 - val_loss: 0.6025 - val_acc: 0.7960
#
# Epoch 00013: val_acc did not improve from 0.79920
# Epoch 14/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4450 - acc: 0.8429 - val_loss: 0.5793 - val_acc: 0.8037
#
# Epoch 00014: val_acc improved from 0.79920 to 0.80370, saving model to /content/gdrive/My Drive/Raajesh-14-0.80.hdf5
# Epoch 15/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4221 - acc: 0.8498 - val_loss: 0.6707 - val_acc: 0.7723
#
# Epoch 00015: val_acc did not improve from 0.80370
# Epoch 16/100
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4187 - acc: 0.8518 - val_loss: 0.6155 - val_acc: 0.7888
#
# Epoch 00016: val_acc did not improve from 0.80370
# Epoch 17/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3906 - acc: 0.8622 - val_loss: 0.5528 - val_acc: 0.8154
#
# Epoch 00017: val_acc improved from 0.80370 to 0.81540, saving model to /content/gdrive/My Drive/Raajesh-17-0.82.hdf5
# Epoch 18/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3833 - acc: 0.8653 - val_loss: 0.5693 - val_acc: 0.8139
#
# Epoch 00018: val_acc did not improve from 0.81540
# Epoch 19/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3777 - acc: 0.8667 - val_loss: 0.5565 - val_acc: 0.8149
#
# Epoch 00019: val_acc did not improve from 0.81540
# Epoch 20/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3712 - acc: 0.8686 - val_loss: 0.5611 - val_acc: 0.8175
#
# Epoch 00020: val_acc improved from 0.81540 to 0.81750, saving model to /content/gdrive/My Drive/Raajesh-20-0.82.hdf5
# Epoch 21/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.3492 - acc: 0.8766 - val_loss: 0.6050 - val_acc: 0.8043
#
# Epoch 00021: val_acc did not improve from 0.81750
# Epoch 22/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3566 - acc: 0.8729 - val_loss: 0.5513 - val_acc: 0.8221
#
# Epoch 00022: val_acc improved from 0.81750 to 0.82210, saving model to /content/gdrive/My Drive/Raajesh-22-0.82.hdf5
# Epoch 23/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3372 - acc: 0.8799 - val_loss: 0.5984 - val_acc: 0.7999
#
# Epoch 00023: val_acc did not improve from 0.82210
# Epoch 24/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3292 - acc: 0.8850 - val_loss: 0.5493 - val_acc: 0.8226
#
# Epoch 00024: val_acc improved from 0.82210 to 0.82260, saving model to /content/gdrive/My Drive/Raajesh-24-0.82.hdf5
# Epoch 25/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3205 - acc: 0.8848 - val_loss: 0.5376 - val_acc: 0.8252
#
# Epoch 00025: val_acc improved from 0.82260 to 0.82520, saving model to /content/gdrive/My Drive/Raajesh-25-0.83.hdf5
# Epoch 26/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3099 - acc: 0.8903 - val_loss: 0.5568 - val_acc: 0.8205
#
# Epoch 00026: val_acc did not improve from 0.82520
# Epoch 27/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3041 - acc: 0.8913 - val_loss: 0.5520 - val_acc: 0.8216
#
# Epoch 00027: val_acc did not improve from 0.82520
# Epoch 28/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3004 - acc: 0.8932 - val_loss: 0.5405 - val_acc: 0.8259
#
# Epoch 00028: val_acc improved from 0.82520 to 0.82590, saving model to /content/gdrive/My Drive/Raajesh-28-0.83.hdf5
# Epoch 29/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2931 - acc: 0.8976 - val_loss: 0.5140 - val_acc: 0.8412
#
# Epoch 00029: val_acc improved from 0.82590 to 0.84120, saving model to /content/gdrive/My Drive/Raajesh-29-0.84.hdf5
# Epoch 30/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2882 - acc: 0.8968 - val_loss: 0.5377 - val_acc: 0.8329
#
# Epoch 00030: val_acc did not improve from 0.84120
# Epoch 31/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2793 - acc: 0.9024 - val_loss: 0.5235 - val_acc: 0.8344
#
# Epoch 00031: val_acc did not improve from 0.84120
# Epoch 32/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2818 - acc: 0.9005 - val_loss: 0.5090 - val_acc: 0.8380
#
# Epoch 00032: val_acc did not improve from 0.84120
# Epoch 33/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2622 - acc: 0.9082 - val_loss: 0.5916 - val_acc: 0.8243
#
# Epoch 00033: val_acc did not improve from 0.84120
# Epoch 34/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.2695 - acc: 0.9050 - val_loss: 0.5356 - val_acc: 0.8350
#
# Epoch 00034: val_acc did not improve from 0.84120
# Epoch 35/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2666 - acc: 0.9061 - val_loss: 0.5378 - val_acc: 0.8380
#
# Epoch 00035: val_acc did not improve from 0.84120
# Epoch 36/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2631 - acc: 0.9062 - val_loss: 0.5416 - val_acc: 0.8251
#
# Epoch 00036: val_acc did not improve from 0.84120
# Epoch 37/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.2506 - acc: 0.9121 - val_loss: 0.6335 - val_acc: 0.8068
#
# Epoch 00037: val_acc did not improve from 0.84120
# Epoch 38/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2615 - acc: 0.9059 - val_loss: 0.5117 - val_acc: 0.8354
#
# Epoch 00038: val_acc did not improve from 0.84120
# Epoch 39/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2510 - acc: 0.9102 - val_loss: 0.5251 - val_acc: 0.8365
#
# Epoch 00039: val_acc did not improve from 0.84120
# Epoch 40/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2406 - acc: 0.9148 - val_loss: 0.5291 - val_acc: 0.8388
#
# Epoch 00040: val_acc did not improve from 0.84120
# Epoch 41/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2428 - acc: 0.9136 - val_loss: 0.5534 - val_acc: 0.8377
#
# Epoch 00041: val_acc did not improve from 0.84120
# Epoch 42/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.2378 - acc: 0.9157 - val_loss: 0.5517 - val_acc: 0.8252
#
# Epoch 00042: val_acc did not improve from 0.84120
# Epoch 43/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2386 - acc: 0.9159 - val_loss: 0.5365 - val_acc: 0.8324
#
# Epoch 00043: val_acc did not improve from 0.84120
# Epoch 44/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2296 - acc: 0.9198 - val_loss: 0.5433 - val_acc: 0.8361
#
# Epoch 00044: val_acc did not improve from 0.84120
# Epoch 45/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2267 - acc: 0.9205 - val_loss: 0.5756 - val_acc: 0.8252
#
# Epoch 00045: val_acc did not improve from 0.84120
# Epoch 46/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.2315 - acc: 0.9191 - val_loss: 0.5274 - val_acc: 0.8409
#
# Epoch 00046: val_acc did not improve from 0.84120
# Epoch 47/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2294 - acc: 0.9194 - val_loss: 0.5209 - val_acc: 0.8399
#
# Epoch 00047: val_acc did not improve from 0.84120
# Epoch 48/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2247 - acc: 0.9207 - val_loss: 0.5246 - val_acc: 0.8459
#
# Epoch 00048: val_acc improved from 0.84120 to 0.84590, saving model to /content/gdrive/My Drive/Raajesh-48-0.85.hdf5
# Epoch 49/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2232 - acc: 0.9229 - val_loss: 0.5455 - val_acc: 0.8349
#
# Epoch 00049: val_acc did not improve from 0.84590
# Epoch 50/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2261 - acc: 0.9204 - val_loss: 0.5402 - val_acc: 0.8330
#
# Epoch 00050: val_acc did not improve from 0.84590
# Epoch 51/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.2157 - acc: 0.9227 - val_loss: 0.5496 - val_acc: 0.8392
#
# Epoch 00051: val_acc did not improve from 0.84590
# Epoch 52/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2175 - acc: 0.9239 - val_loss: 0.5144 - val_acc: 0.8400
#
# Epoch 00052: val_acc did not improve from 0.84590
# Epoch 53/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2060 - acc: 0.9265 - val_loss: 0.5256 - val_acc: 0.8419
#
# Epoch 00053: val_acc did not improve from 0.84590
# Epoch 54/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2058 - acc: 0.9271 - val_loss: 0.5014 - val_acc: 0.8484
#
# Epoch 00054: val_acc improved from 0.84590 to 0.84840, saving model to /content/gdrive/My Drive/Raajesh-54-0.85.hdf5
# Epoch 55/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.2041 - acc: 0.9274 - val_loss: 0.5172 - val_acc: 0.8437
#
# Epoch 00055: val_acc did not improve from 0.84840
# Epoch 56/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2036 - acc: 0.9287 - val_loss: 0.5175 - val_acc: 0.8519
#
# Epoch 00056: val_acc improved from 0.84840 to 0.85190, saving model to /content/gdrive/My Drive/Raajesh-56-0.85.hdf5
# Epoch 57/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1973 - acc: 0.9311 - val_loss: 0.4960 - val_acc: 0.8464
#
# Epoch 00057: val_acc did not improve from 0.85190
# Epoch 58/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1966 - acc: 0.9305 - val_loss: 0.5473 - val_acc: 0.8457
#
# Epoch 00058: val_acc did not improve from 0.85190
# Epoch 59/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1981 - acc: 0.9311 - val_loss: 0.5487 - val_acc: 0.8374
#
# Epoch 00059: val_acc did not improve from 0.85190
# Epoch 60/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1948 - acc: 0.9317 - val_loss: 0.5282 - val_acc: 0.8430
#
# Epoch 00060: val_acc did not improve from 0.85190
# Epoch 61/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1916 - acc: 0.9331 - val_loss: 0.5118 - val_acc: 0.8446
#
# Epoch 00061: val_acc did not improve from 0.85190
# Epoch 62/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1918 - acc: 0.9323 - val_loss: 0.5370 - val_acc: 0.8400
#
# Epoch 00062: val_acc did not improve from 0.85190
# Epoch 63/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1887 - acc: 0.9330 - val_loss: 0.5076 - val_acc: 0.8502
#
# Epoch 00063: val_acc did not improve from 0.85190
# Epoch 64/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1888 - acc: 0.9330 - val_loss: 0.4974 - val_acc: 0.8447
#
# Epoch 00064: val_acc did not improve from 0.85190
# Epoch 65/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1888 - acc: 0.9330 - val_loss: 0.5354 - val_acc: 0.8426
#
# Epoch 00065: val_acc did not improve from 0.85190
# Epoch 66/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1867 - acc: 0.9337 - val_loss: 0.5210 - val_acc: 0.8421
#
# Epoch 00066: val_acc did not improve from 0.85190
# Epoch 67/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1908 - acc: 0.9328 - val_loss: 0.4925 - val_acc: 0.8468
#
# Epoch 00067: val_acc did not improve from 0.85190
# Epoch 68/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1861 - acc: 0.9348 - val_loss: 0.5480 - val_acc: 0.8477
#
# Epoch 00068: val_acc did not improve from 0.85190
# Epoch 69/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1818 - acc: 0.9353 - val_loss: 0.5240 - val_acc: 0.8448
#
# Epoch 00069: val_acc did not improve from 0.85190
# Epoch 70/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1833 - acc: 0.9356 - val_loss: 0.5220 - val_acc: 0.8403
#
# Epoch 00070: val_acc did not improve from 0.85190
# Epoch 71/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1778 - acc: 0.9379 - val_loss: 0.5337 - val_acc: 0.8437
#
# Epoch 00071: val_acc did not improve from 0.85190
# Epoch 72/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1781 - acc: 0.9376 - val_loss: 0.5484 - val_acc: 0.8355
#
# Epoch 00072: val_acc did not improve from 0.85190
# Epoch 73/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1767 - acc: 0.9383 - val_loss: 0.5050 - val_acc: 0.8504
#
# Epoch 00073: val_acc did not improve from 0.85190
# Epoch 74/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1738 - acc: 0.9390 - val_loss: 0.6135 - val_acc: 0.8197
#
# Epoch 00074: val_acc did not improve from 0.85190
# Epoch 75/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1780 - acc: 0.9377 - val_loss: 0.5234 - val_acc: 0.8474
#
# Epoch 00075: val_acc did not improve from 0.85190
# Epoch 76/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1734 - acc: 0.9383 - val_loss: 0.5819 - val_acc: 0.8464
#
# Epoch 00076: val_acc did not improve from 0.85190
# Epoch 77/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1709 - acc: 0.9402 - val_loss: 0.5236 - val_acc: 0.8520
#
# Epoch 00077: val_acc improved from 0.85190 to 0.85200, saving model to /content/gdrive/My Drive/Raajesh-77-0.85.hdf5
# Epoch 78/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1718 - acc: 0.9394 - val_loss: 0.5349 - val_acc: 0.8455
#
# Epoch 00078: val_acc did not improve from 0.85200
# Epoch 79/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1665 - acc: 0.9410 - val_loss: 0.4953 - val_acc: 0.8508
#
# Epoch 00079: val_acc did not improve from 0.85200
# Epoch 80/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1679 - acc: 0.9417 - val_loss: 0.5024 - val_acc: 0.8466
#
# Epoch 00080: val_acc did not improve from 0.85200
# Epoch 81/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1670 - acc: 0.9415 - val_loss: 0.5026 - val_acc: 0.8472
#
# Epoch 00081: val_acc did not improve from 0.85200
# Epoch 82/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1634 - acc: 0.9428 - val_loss: 0.5181 - val_acc: 0.8533
#
# Epoch 00082: val_acc improved from 0.85200 to 0.85330, saving model to /content/gdrive/My Drive/Raajesh-82-0.85.hdf5
# Epoch 83/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1630 - acc: 0.9432 - val_loss: 0.4943 - val_acc: 0.8513
#
# Epoch 00083: val_acc did not improve from 0.85330
# Epoch 84/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1642 - acc: 0.9414 - val_loss: 0.5166 - val_acc: 0.8571
#
# Epoch 00084: val_acc improved from 0.85330 to 0.85710, saving model to /content/gdrive/My Drive/Raajesh-84-0.86.hdf5
# Epoch 85/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1642 - acc: 0.9417 - val_loss: 0.5217 - val_acc: 0.8521
#
# Epoch 00085: val_acc did not improve from 0.85710
# Epoch 86/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1623 - acc: 0.9434 - val_loss: 0.5430 - val_acc: 0.8450
#
# Epoch 00086: val_acc did not improve from 0.85710
# Epoch 87/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1612 - acc: 0.9431 - val_loss: 0.5023 - val_acc: 0.8547
#
# Epoch 00087: val_acc did not improve from 0.85710
# Epoch 88/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1593 - acc: 0.9451 - val_loss: 0.5341 - val_acc: 0.8540
#
# Epoch 00088: val_acc did not improve from 0.85710
# Epoch 89/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1568 - acc: 0.9449 - val_loss: 0.5509 - val_acc: 0.8435
#
# Epoch 00089: val_acc did not improve from 0.85710
# Epoch 90/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1541 - acc: 0.9453 - val_loss: 0.5134 - val_acc: 0.8588
#
# Epoch 00090: val_acc improved from 0.85710 to 0.85880, saving model to /content/gdrive/My Drive/Raajesh-90-0.86.hdf5
# Epoch 91/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1584 - acc: 0.9436 - val_loss: 0.5230 - val_acc: 0.8598
#
# Epoch 00091: val_acc improved from 0.85880 to 0.85980, saving model to /content/gdrive/My Drive/Raajesh-91-0.86.hdf5
# Epoch 92/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1560 - acc: 0.9451 - val_loss: 0.5085 - val_acc: 0.8461
#
# Epoch 00092: val_acc did not improve from 0.85980
# Epoch 93/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.1539 - acc: 0.9457 - val_loss: 0.5141 - val_acc: 0.8561
#
# Epoch 00093: val_acc did not improve from 0.85980
# Epoch 94/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1556 - acc: 0.9457 - val_loss: 0.4808 - val_acc: 0.8524
#
# Epoch 00094: val_acc did not improve from 0.85980
# Epoch 95/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1500 - acc: 0.9474 - val_loss: 0.5281 - val_acc: 0.8522
#
# Epoch 00095: val_acc did not improve from 0.85980
# Epoch 96/100
# 390/390 [==============================] - 35s 88ms/step - loss: 0.1498 - acc: 0.9477 - val_loss: 0.5173 - val_acc: 0.8569
#
# Epoch 00096: val_acc did not improve from 0.85980
# Epoch 97/100
# 390/390 [==============================] - 34s 88ms/step - loss: 0.1520 - acc: 0.9467 - val_loss: 0.5158 - val_acc: 0.8495
#
# Epoch 00097: val_acc did not improve from 0.85980
# Epoch 98/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1469 - acc: 0.9485 - val_loss: 0.5300 - val_acc: 0.8501
#
# Epoch 00098: val_acc did not improve from 0.85980
# Epoch 99/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1500 - acc: 0.9466 - val_loss: 0.5049 - val_acc: 0.8472
#
# Epoch 00099: val_acc did not improve from 0.85980
# Epoch 100/100
# 390/390 [==============================] - 35s 89ms/step - loss: 0.1471 - acc: 0.9488 - val_loss: 0.5444 - val_acc: 0.8449
#
# Epoch 00100: val_acc did not improve from 0.85980
# Model took 3473.60 seconds to train
# Accuracy on test data is: 84.49

# %%
model.load_weights('/content/gdrive/My Drive/Raajesh-91-0.86.hdf5')

# %% [markdown]
# #### USING GRADCAM TO VIEW SAME 4 IMAGES

# %%
(Train_features, Train_labels),(Test_features,Test_labels) = cifar10.load_data()

# %%
Train_features = Train_features.astype('float32')/255
Test_features = Test_features.astype('float32')/255

# %%
for n in classified_array:
  gradcam(n)

# %%
def gradcam(image_number):
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
  test_features = test_features.astype('float32')/255
  test_labels = np_utils.to_categorical(test_labels, num_classes)  
  img = test_features[image_number]
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  #x = preprocess_input(x)  
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_8") 
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(192):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)  
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()  
  img = test_features[image_number]
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  #from google.colab.patches import cv2_imshow
  img = cv2.resize(img,(224,224))
  superimposed_img = cv2.resize(superimposed_img,(224,224))
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  #cv2.waitKey(0)
  con = np.concatenate((img, superimposed_img), axis = 0)
  true = int(Test_labels[image_number])
  pred = int(predicted_classes[image_number])
  plt.title("True Class: " + str(class_names[true])+"    Pred Class: " + str(class_names[pred]))
  plt.imshow(con)
  plt.show()
  #plt.imshow(superimposed_img)
  #plt.title("predicted :",str(labels[predicted_classes[127]]))
  plt.axis('off')
  #plt.title("Predicted : " + labels[predicted_classes[image_number]], "True class : " + str(labels[Test_labels[image_number]])
  #plt.show()
  #cv2.waitKey(0)
